# %% [markdown]
# ## Visualizer Example
# The `Visualizer` class responsible for providing charts and plots about a GitHub repository using the `Downloader` class.

# %%
from dotenv import load_dotenv
from hub_visualizer import Visualizer

# for reloading the Downloader after code change
# %reload_ext autoreload
# %autoreload 1
# %aimport hub_visualizer

# loading environment variables from .env file
load_dotenv();

# %%
owner = 'pandas-dev'
repo = 'pandas'
pandas_visualizer = Visualizer(owner, repo)

# %%
pandas_visualizer.commit_activity()

# %%
pandas_visualizer.stargazer_history()

# %%
pandas_visualizer.commits_by_author(limit=15)

# %%
pandas_visualizer.lines_over_time()
